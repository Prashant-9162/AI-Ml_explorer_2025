# %%
import pandas

# %%
dataset = pandas.read_csv("mrks_sheet1.csv.")

# %%
type (dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset
# Out:
#     name  hrs  mrks
# 0  harry    4    40
# 1   erik    6    60
# 2   yash    9    90
# 3  krish    2    20

# %%
dataset.columns
# Out:
# Index(['name', 'hrs', 'mrks'], dtype='object')

# %%
y = dataset['mrks']

# %% [markdown]
# y

# %%
x=dataset['hrs']

# %%
x
# Out:
# 0    4
# 1    6
# 2    9
# 3    2
# Name: hrs, dtype: int64

# %%
x.shape
# Out:
# (4,)

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x.values
# Out:
# array([4, 6, 9, 2], dtype=int64)

# %%
X = x.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
#model learning pattern :model build
model.fit(X , y)
# Out:
# LinearRegression()

# %%
model.predict([[ 9 ]])
# Out:
# array([90.])

# %%
model.predict([[ 5 ]])
# Out:
# array([50.])

# %%
x=5
y=10*x
print(y)
# Out:
# 50

# %%
model.coef_
# Out:
# array([10.])

# %%
model.intercept_
# Out:
# 7.105427357601002e-15

# %%
import joblib

# %%
joblib.dump(model , "my_mrks_model")
# Out:
# ['my_mrks_model']
